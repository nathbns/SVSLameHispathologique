# %%
from huggingface_hub import login
login()

# %%
from datasets import Dataset, DatasetDict, Features, Image
import pandas as pd
from pathlib import Path
BASE_DIR = Path("../dataset_patches_256")
META = pd.read_csv(BASE_DIR / "patches_metadata.csv")

def make_split(split_name):
    df = META[META["split"] == split_name].copy()
    df["image"] = df["filename"].apply(lambda f: str(BASE_DIR / split_name / f))
    return Dataset.from_pandas(
        df[["image", "patch_id", "slide_name", "x", "y", "split", "tissue_ratio"]]
    ).cast_column("image", Image())
ds = DatasetDict({
    "train": make_split("train"),
    "validation": make_split("val"),
})
ds.push_to_hub("nathbns/SVS-TCGA-BR")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# ...

# %%
# pour charger normalement ça devrait etre ça après
from datasets import load_dataset
ds = load_dataset("nathbns/SVS-TCGA-BR", split="train")
sample = ds[0]
# Out:
# README.md:   0%|          | 0.00/669 [00:00<?, ?B/s]
# data/train-00000-of-00006.parquet:   0%|          | 0.00/411M [00:00<?, ?B/s]
# data/train-00001-of-00006.parquet:   0%|          | 0.00/514M [00:00<?, ?B/s]
# data/train-00002-of-00006.parquet:   0%|          | 0.00/506M [00:00<?, ?B/s]
# data/train-00003-of-00006.parquet:   0%|          | 0.00/529M [00:00<?, ?B/s]
# data/train-00004-of-00006.parquet:   0%|          | 0.00/567M [00:00<?, ?B/s]
# data/train-00005-of-00006.parquet:   0%|          | 0.00/538M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/347M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/3025 [00:00<?, ? examples/s]

# %%
# montrer image sample.image dans le notebook
import matplotlib.pyplot as plt

img = sample["image"]
plt.imshow(img)
plt.axis("off")
plt.show()
